# %%
# Import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
# Import our input dataset
corporate_giving_df = pd.read_csv("charity_data.csv")
corporate_giving_df
# Out:
#              EIN                                               NAME  \
# 0       10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1       10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2       10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3       10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4       10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# ...          ...                                                ...
# 34294  996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA
# 34295  996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS
# 34296  996012607                                PTA HAWAII CONGRESS
# 34297  996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...
# 34298  996086871                           WATERHOUSE CHARITABLE TR
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 12 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Inspect Data

# %%
if len(corporate_giving_df[corporate_giving_df.duplicated(['EIN'])]) == 0:
    print(f"There are {len(corporate_giving_df[corporate_giving_df.duplicated(['EIN'])])} duplicate EINs; use EIN as index")
else:
    print("Do not use EIN as index")
# Out:
# There are 0 duplicate EINs; use EIN as index

# %%
corporate_giving_df = corporate_giving_df.set_index('EIN')
corporate_giving_df
# Out:
#                                                         NAME APPLICATION_TYPE  \
# EIN
# 10520599                        BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 10531628              AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 10547893                  ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 10553066                      SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 10556103            GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
# ...                                                      ...              ...
# 996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA               T4
# 996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS               T4
# 996012607                                PTA HAWAII CONGRESS               T3
# 996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...               T5
# 996086871                           WATERHOUSE CHARITABLE TR               T3
#
#                 AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  \
# EIN
# 10520599        Independent          C1000    ProductDev   Association
# 10531628        Independent          C2000  Preservation  Co-operative
# 10547893   CompanySponsored          C3000    ProductDev   Association
# 10553066   CompanySponsored          C2000  Preservation         Trust
# 10556103        Independent          C1000     Heathcare         Trust
# ...                     ...            ...           ...           ...
# 996009318       Independent          C1000    ProductDev   Association
# 996010315  CompanySponsored          C3000    ProductDev   Association
# 996012607  CompanySponsored          C2000  Preservation   Association
# 996015768       Independent          C3000    ProductDev   Association
# 996086871       Independent          C1000  Preservation  Co-operative
#
#            STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# EIN
# 10520599        1              0                      N      5000
# 10531628        1         1-9999                      N    108590
# 10547893        1              0                      N      5000
# 10553066        1    10000-24999                      N      6692
# 10556103        1  100000-499999                      N    142590
# ...           ...            ...                    ...       ...
# 996009318       1              0                      N      5000
# 996010315       1              0                      N      5000
# 996012607       1              0                      N      5000
# 996015768       1              0                      N      5000
# 996086871       1          1M-5M                      N  36500179
#
#            IS_SUCCESSFUL
# EIN
# 10520599               1
# 10531628               1
# 10547893               0
# 10553066               1
# 10556103               1
# ...                  ...
# 996009318              0
# 996010315              0
# 996012607              0
# 996015768              1
# 996086871              0
#
# [34299 rows x 11 columns]

# %%
corporate_giving_df.dtypes
# Out:
# NAME                      object
# APPLICATION_TYPE          object
# AFFILIATION               object
# CLASSIFICATION            object
# USE_CASE                  object
# ORGANIZATION              object
# STATUS                     int64
# INCOME_AMT                object
# SPECIAL_CONSIDERATIONS    object
# ASK_AMT                    int64
# IS_SUCCESSFUL              int64
# dtype: object

# %%
corporate_giving_df.nunique(axis=0)
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %% [markdown]
# ### Drop non-informative columns

# %%
corporate_giving_df = corporate_giving_df.drop(['NAME'], axis=1)

# %%
### Bin categorical columns

# %%
corporate_giving_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Binning application type
corporate_giving_df = corporate_giving_df.copy()

app_counts = corporate_giving_df['APPLICATION_TYPE'].value_counts()

replace_app = list(app_counts[app_counts < 500].index)

for app in replace_app:
    corporate_giving_df['APPLICATION_TYPE'] = corporate_giving_df['APPLICATION_TYPE'].replace(app,"Other")
    
corporate_giving_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
corporate_giving_df['CLASSIFICATION'].value_counts().head(35)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1237        9
# C1235        9
# C7210        7
# C4100        6
# C2400        6
# C1720        6
# Name: CLASSIFICATION, dtype: int64

# %%
# Binning classification
class_counts = corporate_giving_df['CLASSIFICATION'].value_counts()

replace_class = list(class_counts[class_counts < 700].index)

for class_ in replace_class:
    corporate_giving_df['CLASSIFICATION'] = corporate_giving_df['CLASSIFICATION'].replace(class_,"Other")
    
corporate_giving_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
corporate_giving_df['SPECIAL_CONSIDERATIONS'] = corporate_giving_df['SPECIAL_CONSIDERATIONS'].replace(to_replace=['N', 'Y'], value=[0, 1])
corporate_giving_df.astype({'SPECIAL_CONSIDERATIONS':'int64'})
corporate_giving_df.head()
# Out:
#          APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# EIN
# 10520599              T10       Independent          C1000    ProductDev
# 10531628               T3       Independent          C2000  Preservation
# 10547893               T5  CompanySponsored          C3000    ProductDev
# 10553066               T3  CompanySponsored          C2000  Preservation
# 10556103               T3       Independent          C1000     Heathcare
#
#           ORGANIZATION  STATUS     INCOME_AMT  SPECIAL_CONSIDERATIONS  \
# EIN
# 10520599   Association       1              0                       0
# 10531628  Co-operative       1         1-9999                       0
# 10547893   Association       1              0                       0
# 10553066         Trust       1    10000-24999                       0
# 10556103         Trust       1  100000-499999                       0
#
#           ASK_AMT  IS_SUCCESSFUL
# EIN
# 10520599     5000              1
# 10531628   108590              1
# 10547893     5000              0
# 10553066     6692              1
# 10556103   142590              1

# %% [markdown]
# ### Encode categorical columns
